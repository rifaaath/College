# %%
import pandas as pd 
df = pd.read_csv('mushrooms.csv')

# %%
df.head()
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
# 3            c         n          n  ...                        s
# 4            w         b          k  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# 1                      w                      w         p          w
# 2                      w                      w         p          w
# 3                      w                      w         p          w
# 4                      w                      w         p          w
#
#   ring-number ring-type spore-print-color population habitat
# 0           o         p                 k          s       u
# 1           o         p                 n          n       g
# 2           o         p                 n          n       m
# 3           o         p                 k          s       u
# 4           o         e                 n          a       g
#
# [5 rows x 23 columns]

# %%
# We need to predict whether the mashroom is poisonous or edible
df_cat = pd.DataFrame()
for i in list(df.columns):
    df_cat['{}_cat'.format(i)] = df[i].astype('category').copy()
    df_cat['{}_cat'.format(i)] = df_cat['{}_cat'.format(i)].cat.codes

# %%
df_cat.head()
# Out:
#    class_cat  cap-shape_cat  cap-surface_cat  cap-color_cat  bruises_cat  \
# 0          1              5                2              4            1
# 1          0              5                2              9            1
# 2          0              0                2              8            1
# 3          1              5                3              8            1
# 4          0              5                2              3            0
#
#    odor_cat  gill-attachment_cat  gill-spacing_cat  gill-size_cat  \
# 0         6                    1                 0              1
# 1         0                    1                 0              0
# 2         3                    1                 0              0
# 3         6                    1                 0              1
# 4         5                    1                 1              0
#
#    gill-color_cat  ...  stalk-surface-below-ring_cat  \
# 0               4  ...                             2
# 1               4  ...                             2
# 2               5  ...                             2
# 3               5  ...                             2
# 4               4  ...                             2
#
#    stalk-color-above-ring_cat  stalk-color-below-ring_cat  veil-type_cat  \
# 0                           7                           7              0
# 1                           7                           7              0
# 2                           7                           7              0
# 3                           7                           7              0
# 4                           7                           7              0
#
#    veil-color_cat  ring-number_cat  ring-type_cat  spore-print-color_cat  \
# 0               2                1              4                      2
# 1               2                1              4                      3
# 2               2                1              4                      3
# 3               2                1              4                      2
# 4               2                1              0                      3
#
#    population_cat  habitat_cat
# 0               3            5
# 1               2            1
# 2               2            3
# 3               3            5
# 4               0            1
#
# [5 rows x 23 columns]

# %%
X = df_cat.drop('class_cat', axis = 1)
y = df_cat['class_cat']

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1, stratify=y)

# %%
forest = RandomForestClassifier(criterion='entropy',
                                 n_estimators=5,
                                 random_state=1,
                                 n_jobs=2)

# %%
# Fit the model
forest.fit(X_train, y_train)
# Out:
# RandomForestClassifier(criterion='entropy', n_estimators=5, n_jobs=2,
#                        random_state=1)

# %%
from sklearn.metrics import accuracy_score
y_pred = forest.predict(X_test)
print('Accuracy: %f' % accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 1.000000
