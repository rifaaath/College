# %%
#Breast Cancer Prediction

# %%
import pandas as pd
from sklearn.datasets import load_breast_cancer

# %%
dataset = load_breast_cancer()
df = pd.DataFrame(dataset.data, columns = dataset.feature_names)
df['label'] = dataset.target

# %%
x = df.drop('label', axis = 1)
y = df['label']

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2)

# %%
from keras.models import Sequential
from keras.layers import Dense, Flatten

model = Sequential()
model.add(Flatten(input_shape=(30,)))
model.add(Dense(20, activation = 'relu'))
model.add(Dense(2, activation = 'sigmoid'))
# Out:
# Metal device set to: Apple M1 Pro
# 2023-05-15 09:45:38.752929: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-05-15 09:45:38.753203: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
hist = model.fit(x_train, y_train, validation_split=0.1, epochs=10)
# Out:
# Epoch 1/10
# /Users/ameen/tensorflow-test/env/lib/python3.8/site-packages/keras/engine/data_adapter.py:1508: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   return t[start:end]
# 2023-05-15 09:46:18.651259: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2023-05-15 09:46:18.795284: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 13/13 [==============================] - 2s 37ms/step - loss: 22.8042 - accuracy: 0.4866 - val_loss: 1.4456 - val_accuracy: 0.8696
# Epoch 2/10
# 2023-05-15 09:46:20.015474: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 13/13 [==============================] - 0s 7ms/step - loss: 4.0322 - accuracy: 0.7848 - val_loss: 0.1886 - val_accuracy: 0.9348
# Epoch 3/10
# 13/13 [==============================] - 0s 8ms/step - loss: 1.3086 - accuracy: 0.8240 - val_loss: 0.0976 - val_accuracy: 0.9783
# Epoch 4/10
# 13/13 [==============================] - 0s 8ms/step - loss: 0.7259 - accuracy: 0.9046 - val_loss: 0.3625 - val_accuracy: 0.9130
# Epoch 5/10
# 13/13 [==============================] - 0s 7ms/step - loss: 0.6361 - accuracy: 0.9193 - val_loss: 0.1054 - val_accuracy: 0.9783
# Epoch 6/10
# 13/13 [==============================] - 0s 8ms/step - loss: 0.5102 - accuracy: 0.9291 - val_loss: 0.1699 - val_accuracy: 0.9348
# Epoch 7/10
# 13/13 [==============================] - 0s 7ms/step - loss: 0.4472 - accuracy: 0.9218 - val_loss: 0.0929 - val_accuracy: 0.9565
# Epoch 8/10
# 13/13 [==============================] - 0s 7ms/step - loss: 0.4734 - accuracy: 0.9218 - val_loss: 0.1944 - val_accuracy: 0.9348
# Epoch 9/10
# 13/13 [==============================] - 0s 8ms/step - loss: 0.4804 - accuracy: 0.9291 - val_loss: 0.0971 - val_accuracy: 0.9565
# Epoch 10/10
# 13/13 [==============================] - 0s 8ms/step - loss: 0.4772 - accuracy: 0.9242 - val_loss: 0.1373 - val_accuracy: 0.9348

# %%
import matplotlib.pyplot as plt

#Plotting
plt.plot(hist.history['accuracy'], label='Train')
plt.plot(hist.history['val_accuracy'], label='Test')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
plt.plot(hist.history['loss'], label='Train')
plt.plot(hist.history['val_loss'], label='Test')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
print('Accuracy:', hist.history['accuracy'][-1])
# Out:
# Accuracy: 0.9242053627967834
