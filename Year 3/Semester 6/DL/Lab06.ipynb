# %%
#Handwritten classification using ANN

# %%
from keras.datasets import mnist

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# %%
x_train = x_train / 255.0
x_test = x_test / 255.0

# %%
from keras.models import Sequential
from keras.layers import Flatten, Dense

model = Sequential()
model.add(Flatten(input_shape=(28, 28)))
model.add(Dense(128, activation='relu'))
model.add(Dense(10, activation='softmax'))

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
hist=model.fit(x_train, y_train, epochs=5, validation_data=(x_test, y_test))
# Out:
# Epoch 1/5
#   19/1875 [..............................] - ETA: 10s - loss: 0.1956 - accuracy: 0.9359
# 2023-05-15 09:53:33.399208: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 1866/1875 [============================>.] - ETA: 0s - loss: 0.1391 - accuracy: 0.9589
# 2023-05-15 09:53:43.538837: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.1391 - accuracy: 0.9588 - val_loss: 0.1032 - val_accuracy: 0.9687
# Epoch 2/5
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0861 - accuracy: 0.9737 - val_loss: 0.0888 - val_accuracy: 0.9734
# Epoch 3/5
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0628 - accuracy: 0.9811 - val_loss: 0.0793 - val_accuracy: 0.9754
# Epoch 4/5
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0478 - accuracy: 0.9849 - val_loss: 0.0724 - val_accuracy: 0.9780
# Epoch 5/5
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0371 - accuracy: 0.9884 - val_loss: 0.0849 - val_accuracy: 0.9751

# %%
import matplotlib.pyplot as plt

#Plotting
plt.plot(hist.history['accuracy'], label='Train')
plt.plot(hist.history['val_accuracy'], label='Test')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
plt.plot(hist.history['loss'], label='Train')
plt.plot(hist.history['val_loss'], label='Test')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
print("Accuracy:", hist.history['accuracy'][-1])
# Out:
# Accuracy: 0.9884333610534668
